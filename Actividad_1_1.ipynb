# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanZP/Actividad_1.1/blob/main/Actividad_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo
from google.colab import files
files.upload()

# %% [markdown]
# Carga de archivo XLSX

# %%
#Carga desde un archivo .xslx sin indice
df = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df.tail()
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# 1421     6  CS12F1040A00      CAS INOX 1/2"ØX3" 400W 127V EXT.30CM
# 1422     6  CS12H1050A00       CAS INOX 1/2"ØX4" 500W 127V EXT30CM
# 1423     3      TUE00394  TUB INOX 5/16"ØX300MM 5300W 220V "M" ESP
# 1424     1      TUA00470  TUB INOX 1/2"ØX500MM 10KW 220V 2 1/2"NPT
# 1425    10       RB00007   FAB  BOBINA DSD1 6 COLOCAR B/NUEVA 488V
#
#       PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# ...

# %% [markdown]
# #Filtros básicos para variables cualitativas

# %%
#Filtro por objeto
filtro1 = df[df['NOMBRE_VENDEDOR']=='LETICIA RAMIREZ HERNANDEZ']
filtro1
#Convertir archivo filtrado a CSV
filtro1.to_csv("Filtro1.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro1.csv")

# %%
#Filtro por filas
#filtro2 = df.iloc[8:24,:] #filas consecutivas
filtro2 = df.iloc[[8,24,100],:] #filas no consecutivas
filtro2
#Convertir archivo filtrado a CSV
filtro2.to_csv("Filtro2.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro2.csv")

# %%
#Filtro por columnas
#filtro3 = df.iloc[:,2:8] #Columnas consecutivas
filtro3 = df.iloc[:,[2,3,7,9]] #Columnas no consecutivas
filtro3
#Convertir archivo filtrado a CSV
filtro3.to_csv("Filtro3.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro3.csv")

# %%
#Carga desde un archivo .xslx con indice
df1 = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=0)
df1.head()
# Out:
#          FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# CVE_DOC
# F37034  2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# F37036  2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# F37041  2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# F37042  2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# F37043  2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#          CANT   CVE_ART                                    DESCR  \
# CVE_DOC
# F37034      1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V
# F37036      1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT
# F37041      7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT
# F37042      1    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT
# F37043      2   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR
#
#          PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# CVE_DOC
# ...

# %%
#Paso 2: Aplicamos filtro de filas vs columnas
filtro4 = df1.loc[['F37043'],['COSTO_TOTAL_CALCULADO']]
filtro4
#Convertir archivo filtrado a CSV
filtro4.to_csv("Filtro4.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro4.csv")

# %%
#Filtro por cabecera
filtro5 = df.head(15)
filtro5
#Convertir archivo filtrado a CSV
filtro5.to_csv("Filtro5.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro5.csv")

# %% [markdown]
# #Filtros básicos para variables cuantitativas

# %%
#Filtro por comparación
filtro6 = df[df['COSTO_TOTAL_CALCULADO']>20000]
filtro6
#Convertir archivo filtrado a CSV
filtro6.to_csv("Filtro6.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro6.csv")

# %% [markdown]
# #Filtros básicos con conectores lógicos

# %%
#Filtro Y
filtro7 = df[(df['COSTO_TOTAL_CALCULADO']<20000) & (df['PRECIO_UNITARIO']>14000)]
filtro7
#Convertir archivo filtrado a CSV
filtro7.to_csv("Filtro7.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro7.csv")

# %%
#Filtro O
filtro8 = df[(df['CVE_ART']=='TUE00244') | (df['DESCR']=='TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V')]
filtro8
#Convertir archivo filtrado a CSV
filtro8.to_csv("Filtro8.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro8.csv")

# %%
#Filtro not
filtro9 = df[~(df['NOMBRE_VENDEDOR']=='DIEGO ARMANDO LEON DURAN')]
filtro9.head()
#Convertir archivo filtrado a CSV
filtro9.to_csv("Filtro9.csv")
#Descargar archivo filtrado en csv
from google.colab import files
files.download("Filtro9.csv")
